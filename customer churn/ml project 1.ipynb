# %% [markdown]
# # Importing and Loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

# %%
df=pd.read_csv(r"C:\Users\Raju\OneDrive\Desktop\tekspy\customer_churn_dataset-training-master.csv")

# %% [markdown]
# # Data Handling

# %%
df.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0

# %%
df.tail()
# Out:
#         CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 440828    449995.0  42.0    Male    54.0             15.0            1.0
# 440829    449996.0  25.0  Female     8.0             13.0            1.0
# 440830    449997.0  26.0    Male    35.0             27.0            1.0
# 440831    449998.0  28.0    Male    55.0             14.0            2.0
# 440832    449999.0  31.0    Male    48.0             20.0            1.0
#
#         Payment Delay Subscription Type Contract Length  Total Spend  \
# 440828            3.0           Premium          Annual       716.38
# 440829           20.0           Premium          Annual       745.38
# 440830            5.0          Standard       Quarterly       977.31
# 440831            0.0          Standard       Quarterly       602.55
# 440832           14.0           Premium       Quarterly       567.77
#
#         Last Interaction  Churn
# 440828               8.0    0.0
# 440829               2.0    0.0
# ...

# %%
df.describe()
# Out:
#           CustomerID            Age         Tenure  Usage Frequency  \
# count  440832.000000  440832.000000  440832.000000    440832.000000
# mean   225398.667955      39.373153      31.256336        15.807494
# std    129531.918550      12.442369      17.255727         8.586242
# min         2.000000      18.000000       1.000000         1.000000
# 25%    113621.750000      29.000000      16.000000         9.000000
# 50%    226125.500000      39.000000      32.000000        16.000000
# 75%    337739.250000      48.000000      46.000000        23.000000
# max    449999.000000      65.000000      60.000000        30.000000
#
#        Support Calls  Payment Delay    Total Spend  Last Interaction  \
# count  440832.000000  440832.000000  440832.000000     440832.000000
# mean        3.604437      12.965722     631.616223         14.480868
# std         3.070218       8.258063     240.803001          8.596208
# min         0.000000       0.000000     100.000000          1.000000
# ...

# %%
df.sample()
# Out:
#         CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 300827    307941.0  26.0  Female    43.0             17.0            0.0
#
#         Payment Delay Subscription Type Contract Length  Total Spend  \
# 300827            1.0           Premium          Annual       536.49
#
#         Last Interaction  Churn
# 300827              13.0    0.0

# %%
df.shape
# Out:
# (440833, 12)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#        'Support Calls', 'Payment Delay', 'Subscription Type',
#        'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=440833, step=1),
#  Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'Usage Frequency',
#         'Support Calls', 'Payment Delay', 'Subscription Type',
#         'Contract Length', 'Total Spend', 'Last Interaction', 'Churn'],
#        dtype='object')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440833 entries, 0 to 440832
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         440832 non-null  float64
#  1   Age                440832 non-null  float64
#  2   Gender             440832 non-null  object
#  3   Tenure             440832 non-null  float64
#  4   Usage Frequency    440832 non-null  float64
#  5   Support Calls      440832 non-null  float64
#  6   Payment Delay      440832 non-null  float64
#  7   Subscription Type  440832 non-null  object
#  8   Contract Length    440832 non-null  object
#  9   Total Spend        440832 non-null  float64
#  10  Last Interaction   440832 non-null  float64
#  11  Churn              440832 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 40.4+ MB

# %%
df.dtypes
# Out:
# CustomerID           float64
# Age                  float64
# Gender                object
# Tenure               float64
# Usage Frequency      float64
# Support Calls        float64
# Payment Delay        float64
# Subscription Type     object
# Contract Length       object
# Total Spend          float64
# Last Interaction     float64
# Churn                float64
# dtype: object

# %%
df.values
# Out:
# array([[2.0, 30.0, 'Female', ..., 932.0, 17.0, 1.0],
#        [3.0, 65.0, 'Female', ..., 557.0, 6.0, 1.0],
#        [4.0, 55.0, 'Female', ..., 185.0, 3.0, 1.0],
#        ...,
#        [449997.0, 26.0, 'Male', ..., 977.31, 9.0, 0.0],
#        [449998.0, 28.0, 'Male', ..., 602.55, 2.0, 0.0],
#        [449999.0, 31.0, 'Male', ..., 567.77, 21.0, 0.0]],
#       shape=(440833, 12), dtype=object)

# %%
df['Subscription Type'].loc[546]
# Out:
# 'Standard'

# %%
df['Gender'].loc[4567]
# Out:
# 'Female'

# %% [markdown]
# # Data Cleaning

# %%
df.isna().sum()
# Out:
# CustomerID           1
# Age                  1
# Gender               1
# Tenure               1
# Usage Frequency      1
# Support Calls        1
# Payment Delay        1
# Subscription Type    1
# Contract Length      1
# Total Spend          1
# Last Interaction     1
# Churn                1
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#         CustomerID  Age Gender  Tenure  Usage Frequency  Support Calls  \
# 199295         NaN  NaN    NaN     NaN              NaN            NaN
#
#         Payment Delay Subscription Type Contract Length  Total Spend  \
# 199295            NaN               NaN             NaN          NaN
#
#         Last Interaction  Churn
# 199295               NaN    NaN

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# Usage Frequency      0
# Support Calls        0
# Payment Delay        0
# Subscription Type    0
# Contract Length      0
# Total Spend          0
# Last Interaction     0
# Churn                0
# dtype: int64

# %% [markdown]
# # Visualation

# %% [markdown]
# ### Outliers

# %%
sns.boxplot(data=df['Age'])
plt.ylabel('Age')
plt.title('Age of Customers')
# Out:
# Text(0.5, 1.0, 'Age of Customers')

# %% [markdown]
# ### Univarient

# %%
df['Gender'].value_counts().plot.pie(autopct='%1.1f%%')
plt.ylabel('Customer Strength')
plt.title('Pie Chart of Gender Percentage in Customers')
# Out:
# Text(0.5, 1.0, 'Pie Chart of Gender Percentage in Customers')

# %%
sns.countplot(x='Churn',hue='Gender',data=df)
plt.ylabel('Count of customers')
plt.title('Whose returns are more')
# Out:
# Text(0.5, 1.0, 'Whose returns are more')

# %%
sns.violinplot(x='Contract Length',data=df)
plt.xlabel('Contract Length')
# Out:
# Text(0.5, 0, 'Contract Length')

# %%
df['Support Calls'].value_counts().plot.pie(autopct='%1.1f%%')
plt.ylabel('Percentage of support calls')
plt.title('Customer Support Calls')
# Out:
# Text(0.5, 1.0, 'Customer Support Calls')

# %%
sns.histplot(df['Age'])
plt.xlabel('Age of customers')
plt.ylabel('count of customers')
plt.title('Customers strength with age distribution')
# Out:
# Text(0.5, 1.0, 'Customers strength with age distribution')

# %% [markdown]
# ### Bivarient

# %%
sns.kdeplot(x='Age', y='Total Spend', fill=True, data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Total Spend'>

# %%
plt.figure(figsize=(20,6))
sns.barplot(x='Age',y='Support Calls',data=df)
plt.xlabel('Age of customers')
plt.ylabel('customer Support Calls')
plt.title('Support calls of the Customers')
# Out:
# Text(0.5, 1.0, 'Support calls of the Customers')

# %%
sns.scatterplot(x=df['Payment Delay'], y=df['Age'])
plt.show()

# %%
sns.boxplot(x='Subscription Type',y='Usage Frequency',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Subscription Type', ylabel='Usage Frequency'>

# %%
sns.lineplot(x=df['Age'],y=df['Tenure'])
# Out:
# <Axes: xlabel='Age', ylabel='Tenure'>

# %%
df.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0

# %%
sns.countplot(x='Subscription Type',hue='Churn',data=df)
# Out:
# <Axes: xlabel='Subscription Type', ylabel='count'>

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='Payment Delay', hue='Churn', data=df)
# Out:
# <Axes: xlabel='Payment Delay', ylabel='count'>

# %%
sns.violinplot(x='Contract Length',hue='Churn',data=df)
# Out:
# <Axes: xlabel='Contract Length'>

# %%
sns.histplot(x='Age',hue='Churn',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(8,6))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# # Encoding

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.get_dummies(df)

# %%
x=df.drop(columns='Churn')
y=df[['Churn']]

# %%
x.head()
# Out:
#    CustomerID   Age  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 0         2.0  30.0    39.0             14.0            5.0           18.0
# 1         3.0  65.0    49.0              1.0           10.0            8.0
# 2         4.0  55.0    14.0              4.0            6.0           18.0
# 3         5.0  58.0    38.0             21.0            7.0            7.0
# 4         6.0  23.0    32.0             20.0            5.0            8.0
#
#    Total Spend  Last Interaction  Gender_Female  Gender_Male  \
# 0        932.0              17.0           True        False
# 1        557.0               6.0           True        False
# 2        185.0               3.0           True        False
# 3        396.0              29.0          False         True
# 4        617.0              20.0          False         True
#
#    Subscription Type_Basic  Subscription Type_Premium  \
# 0                    False                      False
# ...

# %%
y.head()
# Out:
#    Churn
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)

# %%
x_train.shape
# Out:
# (352665, 16)

# %%
x_test.shape
# Out:
# (88167, 16)

# %%
y_train.shape
# Out:
# (352665, 1)

# %%
y_test.shape
# Out:
# (88167, 1)

# %%
x_train
# Out:
#         CustomerID   Age  Tenure  Usage Frequency  Support Calls  \
# 170896    175707.0  64.0    28.0             12.0            4.0
# 56774      57857.0  24.0    11.0              9.0            3.0
# 320768    327883.0  28.0    33.0              5.0            0.0
# 144694    149505.0  46.0    60.0             25.0            2.0
# 309934    317049.0  38.0    38.0             13.0            2.0
# ...            ...   ...     ...              ...            ...
# 339800    346915.0  50.0    56.0             19.0            3.0
# 253800    260914.0  32.0    31.0              9.0            1.0
# 210756    216029.0  61.0    15.0             12.0            1.0
# 56088      57139.0  59.0     5.0             27.0            5.0
# 300553    307667.0  21.0    17.0             17.0            2.0
#
#         Payment Delay  Total Spend  Last Interaction  Gender_Female  \
# 170896           23.0       885.00               1.0          False
# ...

# %%
x_test
# Out:
#         CustomerID   Age  Tenure  Usage Frequency  Support Calls  \
# 146546    151357.0  46.0    18.0             11.0            6.0
# 247393    254312.0  41.0    30.0             14.0            7.0
# 85067      87374.0  22.0    29.0              3.0            9.0
# 169486    174297.0  61.0    37.0             15.0            1.0
# 127462    131601.0  19.0    51.0              4.0            7.0
# ...            ...   ...     ...              ...            ...
# 292366    299480.0  22.0    31.0             29.0            0.0
# 5452        5461.0  31.0    55.0             26.0           10.0
# 237520    243969.0  49.0    46.0             21.0            0.0
# 141456    146224.0  59.0    19.0             22.0            1.0
# 185131    189942.0  24.0    35.0             25.0            4.0
#
#         Payment Delay  Total Spend  Last Interaction  Gender_Female  \
# 146546            3.0       977.00              20.0           True
# ...

# %%
y_train
# Out:
#         Churn
# 170896    1.0
# 56774     1.0
# 320768    0.0
# 144694    1.0
# 309934    0.0
# ...       ...
# 339800    0.0
# 253800    0.0
# 210756    1.0
# 56088     1.0
# 300553    0.0
#
# [352665 rows x 1 columns]

# %%
y_test
# Out:
#         Churn
# 146546    1.0
# 247393    1.0
# 85067     1.0
# 169486    1.0
# 127462    1.0
# ...       ...
# 292366    0.0
# 5452      1.0
# 237520    1.0
# 141456    1.0
# 185131    1.0
#
# [88167 rows x 1 columns]

# %% [markdown]
# ### Feature Scaling

# %%
scaler=MinMaxScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.fit_transform(x_test)

# %%
print(x_train_scaled)
# Out:
# [[0.39045816 0.9787234  0.45762712 ... 1.         0.         0.        ]
#  [0.12856752 0.12765957 0.16949153 ... 0.         1.         0.        ]
#  [0.7286293  0.21276596 0.54237288 ... 0.         0.         1.        ]
#  ...
#  [0.4800632  0.91489362 0.23728814 ... 0.         0.         1.        ]
#  [0.12697196 0.87234043 0.06779661 ... 0.         0.         1.        ]
#  [0.68370456 0.06382979 0.27118644 ... 0.         0.         1.        ]]

# %%
print(x_test_scaled)
# Out:
# [[0.33633125 0.59574468 0.28813559 ... 0.         0.         1.        ]
#  [0.56513082 0.4893617  0.49152542 ... 0.         0.         1.        ]
#  [0.19414017 0.08510638 0.47457627 ... 0.         1.         0.        ]
#  ...
#  [0.5421453  0.65957447 0.76271186 ... 0.         0.         1.        ]
#  [0.32492405 0.87234043 0.30508475 ... 0.         1.         0.        ]
#  [0.4220797  0.12765957 0.57627119 ... 0.         1.         0.        ]]

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
model=LogisticRegression()
model.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
pred=model.predict(x_test_scaled)

# %%
print('Accuracy_score:',accuracy_score(y_test,pred))
print('confusion matrix:\n',confusion_matrix(y_test,pred))
print('classification_report:\n',classification_report(y_test,pred))
# Out:
# Accuracy_score: 0.9804461986911203
# confusion matrix:
#  [[37302   784]
#  [  940 49141]]
# classification_report:
#                precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98     38086
#          1.0       0.98      0.98      0.98     50081
#
#     accuracy                           0.98     88167
#    macro avg       0.98      0.98      0.98     88167
# weighted avg       0.98      0.98      0.98     88167

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
#Decision Tree
model=DecisionTreeClassifier(random_state=42)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred=model.predict(x_test)
print('Decision Tree Accuracy:',accuracy_score(y_test,y_pred))
# Out:
# Decision Tree Accuracy: 0.9997958419816938

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier(n_estimators=100,max_depth=None,random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=model.predict(x_test)
print('Random Forest Accuracy:',accuracy_score(y_test,y_pred))
# Out:
# Random Forest Accuracy: 0.9997051050846689
